# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.optimize import curve_fit
from scipy.constants import speed_of_light as c
from scipy.constants import pi
from scipy.constants import hbar
from scipy import special as spz

# %matplotlib inline

# %%
x = np.linspace(4.5,5.5,1000)*10**-6
lambda_0 = 1050*10**-9
k_0 = 2*pi/lambda_0
delta_lambda = 1*10**-9
delta_k = 2*pi/lambda_0**2*delta_lambda
sin_squared = np.sin(k_0*x)**2
sin_squared_2 = np.sin((k_0-delta_k)*x)**2

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1, 1, 1)
plt.plot(x,sin_squared)
plt.plot(x,sin_squared_2)
plt.show()
np.disp(k_0)
np.disp(delta_k)
# Out:
# 5983986.0068377005
# 5699.034292226381

# %%
delta_l = np.linspace(-1,1,100)*10**-9
delta_x_0 = 5*lambda_0*(1-1/(1+delta_l/lambda_0))
plt.plot(delta_l,delta_x_0)
plt.show()

# %%
5*lambda_0/(1+0*10**-9/lambda_0) - 5*lambda_0/(1+1*10**-9/lambda_0)
# Out:
# 4.995242626071119e-09

# %%
V = 40
q = V/4
bandnumber = np.arange(1,5+1)
offset = np.floor_divide(bandnumber,2)*(-1)**(np.mod(bandnumber,2))
offset = offset.reshape(1,offset.size)
r = np.linspace(-1,1,1000,endpoint=True)
r = r.reshape(r.size,1)
#doesnt work lik ein mathematica

a = spz.mathieu_a(r-offset,q)*np.heaviside(r,-0.5)+spz.mathieu_a(r+offset,q)*np.heaviside(r,+0.5)
E = a+V/2

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1, 1, 1)
plt.plot(r,E)
plt.show()

# %%
(-1)**(np.mod(bandnumber,2))
np.floor_divide(bandnumber,2)
# Out:
# array([0, 1, 1, 2, 2])

# %%
a
# Out:
# array([[        nan,         nan,         nan,         nan,         nan],
#        [        nan,         nan,         nan,         nan,         nan],
#        [        nan,         nan,         nan,         nan,         nan],
#        ...,
#        [        nan,         nan,         nan,         nan,         nan],
#        [        nan,         nan,         nan,         nan,         nan],
#        [-4.7982848 , -6.21961011, -6.21961011,         nan,         nan]])

# %%
spz.mathieu_cem(1,q,pi/2/pi*180)
# Out:
# (-2.086068336889298e-15, -4.850438304496397)

# %%
V = 40
k_L = 1064*10**-9
m_Li6 = 9.89*10**-27
E_R = hbar**2*k_L**2/(2*m_Li6)
trapping_freq = np.sqrt(V*E_R*2*k_L**2/m_Li6)
np.disp(trapping_freq)
# Out:
# 7.63471999515238e-20
